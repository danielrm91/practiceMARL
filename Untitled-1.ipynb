# %%
# %run mappo_minimal_template
# Out:
# Update 0000 | rollout return: -522.00
# Update 0010 | rollout return: -458.33
# Update 0020 | rollout return: -351.67
# Update 0030 | rollout return: -262.33
# Update 0040 | rollout return: -162.00
# Update 0050 | rollout return: -72.00
# Update 0060 | rollout return: -34.67
# Update 0070 | rollout return: -26.33
# Update 0080 | rollout return: -8.00
# Update 0090 | rollout return: -3.00
# Update 0100 | rollout return: -1.00
# Update 0110 | rollout return: 0.00
# Update 0120 | rollout return: -0.33
# Update 0130 | rollout return: 0.00
# Update 0140 | rollout return: 0.00
# Update 0150 | rollout return: 0.00
# Update 0160 | rollout return: 0.00
# Update 0170 | rollout return: 0.00
# Update 0180 | rollout return: 0.00
# Update 0190 | rollout return: 0.00
# Update 0200 | rollout return: 0.00
# Update 0210 | rollout return: 0.00
# Update 0220 | rollout return: 0.00
# Update 0230 | rollout return: 0.00
# Update 0240 | rollout return: 0.00
# Update 0250 | rollout return: 0.00
# ...
